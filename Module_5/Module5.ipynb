# %% [markdown]
# # **MODULE 5**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
import re

# %%
infosys_df = pd.read_csv("/content/drive/My Drive/DataScience/Aspiration Internship/week2.csv")

# %%
infosys_df.head()
# Out:
#   Symbol Series        Date  ...        vwap  PCT_change                Trend
# 0   INFY     EQ  2017-05-15  ...  951.550000    0.000000  Slight or No change
# 1   INFY     EQ  2017-05-16  ...  953.125077    0.003626  Slight or No change
# 2   INFY     EQ  2017-05-17  ...  953.067084   -0.002304  Slight or No change
# 3   INFY     EQ  2017-05-18  ...  955.934447    0.009393      Slight positive
# 4   INFY     EQ  2017-05-19  ...  956.233874   -0.003951  Slight or No change
#
# [5 rows x 20 columns]

# %%
infosys_df['Date']=pd.to_datetime(infosys_df['Date'])

# %%
infosys_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Symbol                  494 non-null    object
#  1   Series                  494 non-null    object
#  2   Date                    494 non-null    datetime64[ns]
#  3   Prev Close              494 non-null    float64
#  4   Open Price              494 non-null    float64
#  5   High Price              494 non-null    float64
#  6   Low Price               494 non-null    float64
#  7   Last Price              494 non-null    float64
#  8   Close Price             494 non-null    float64
#  9   Average Price           494 non-null    float64
#  10  Total Traded Quantity   494 non-null    int64
#  11  Turnover                494 non-null    float64
#  12  No. of Trades           494 non-null    int64
#  13  Deliverable Qty         494 non-null    int64
# ...

# %%
infosys_df.set_index(infosys_df['Date'], inplace=True)

# %%
infosys_df.head()
# Out:
#            Symbol Series  ... PCT_change                Trend
# Date                      ...
# 2017-05-15   INFY     EQ  ...   0.000000  Slight or No change
# 2017-05-16   INFY     EQ  ...   0.003626  Slight or No change
# 2017-05-17   INFY     EQ  ...  -0.002304  Slight or No change
# 2017-05-18   INFY     EQ  ...   0.009393      Slight positive
# 2017-05-19   INFY     EQ  ...  -0.003951  Slight or No change
#
# [5 rows x 20 columns]

# %%
daily_mean = infosys_df.PCT_change.mean()
daily_mean
# Out:
# -9.352843905651558e-05

# %%
daily_stdev = infosys_df.PCT_change.std()
daily_stdev
# Out:
# 0.026367329989274182

# %%
annual_mean = daily_mean*252
annual_mean
# Out:
# -0.023569166642241925

# %%
annual_stdev = daily_stdev*(math.sqrt(252))
annual_stdev
# Out:
# 0.4185683873303692

# %%
infosys_df.describe()
# Out:
#         Prev Close   Open Price  ...         vwap  PCT_change
# count   494.000000   494.000000  ...   494.000000  494.000000
# mean    961.440789   961.070040  ...   958.478184   -0.000094
# std     220.761549   220.091227  ...   212.332328    0.026367
# min     619.100000   621.000000  ...   646.020002   -0.486038
# 25%     735.025000   736.187500  ...   747.739298   -0.007175
# 50%     956.750000   957.525000  ...   955.958142    0.000755
# 75%    1150.150000  1145.412500  ...  1137.430283    0.009679
# max    1441.100000  1449.000000  ...  1434.250000    0.046811
#
# [8 rows x 16 columns]

# %%
df01 = pd.read_csv("/content/drive/My Drive/DataScience/Aspiration Internship/BAJAJELEC.csv")
print(df01.shape)
index_drop = df01.Series[df01['Series'] != 'EQ'].index
df01.drop(index_drop, inplace=True)
df01['Date']=pd.to_datetime(df01['Date'])
df01.set_index('Date', inplace=True)

df02 = pd.read_csv("/content/drive/My Drive/DataScience/Aspiration Internship/FORTIS.csv")
print(df02.shape)
index_drop = df02.Series[df02['Series'] != 'EQ'].index
df02.drop(index_drop, inplace=True)
df02['Date']=pd.to_datetime(df02['Date'])
df02.set_index('Date', inplace=True)


df03 = pd.read_csv("/content/drive/My Drive/DataScience/Aspiration Internship/IDFC.csv")
print(df03.shape)
index_drop = df03.Series[df03['Series'] != 'EQ'].index
df03.drop(index_drop, inplace=True)
df03['Date']=pd.to_datetime(df03['Date'])
df03.set_index('Date', inplace=True)


df04 = pd.read_csv("/content/drive/My Drive/DataScience/Aspiration Internship/LALPATHLAB.csv")
print(df04.shape)
index_drop = df04.Series[df04['Series'] != 'EQ'].index
df04.drop(index_drop, inplace=True)
df04['Date']=pd.to_datetime(df04['Date'])
df04.set_index('Date', inplace=True)


df05 = pd.read_csv("/content/drive/My Drive/DataScience/Aspiration Internship/JKLAKSHMI.csv")
print(df05.shape)
index_drop = df05.Series[df05['Series'] != 'EQ'].index
df05.drop(index_drop, inplace=True)
df05['Date']=pd.to_datetime(df05['Date'])
df05.set_index('Date', inplace=True)
# Out:
# (494, 15)
# (495, 15)
# (495, 15)
# (495, 15)
# (494, 15)

# %%
print(df01.shape)
print(df02.shape)
print(df03.shape)
print(df04.shape)
print(df05.shape)
# Out:
# (494, 14)
# (494, 14)
# (494, 14)
# (494, 14)
# (494, 14)

# %%
multi_df = pd.DataFrame({'BAJAJELEC':df01['Close Price'],
                                    'FORTIS': df02['Close Price'],
                                    'IDFC':df03['Close Price'],
                                    'LALPATHLAB': df04['Close Price'],
                                    'JKLAKSHMI': df05['Close Price']})

# %%
multi_df.head()
# Out:
#             BAJAJELEC  FORTIS   IDFC  LALPATHLAB  JKLAKSHMI
# Date
# 2017-05-15     341.15  205.25  63.70      900.60     510.80
# 2017-05-16     347.00  207.90  64.25      910.95     527.50
# 2017-05-17     349.85  205.90  63.35      911.70     516.20
# 2017-05-18     334.10  196.85  61.50      909.75     478.95
# 2017-05-19     336.20  203.55  61.15      910.25     469.55

# %%
multi_df_pct_change = pd.DataFrame({'BAJAJELEC':df01['Close Price'].pct_change(),
                                   'FORTIS': df02['Close Price'].pct_change(),
                                    'IDFC':df03['Close Price'].pct_change(),
                                    'LALPATHLAB': df04['Close Price'].pct_change(),
                                    'JKLAKSHMI': df05['Close Price'].pct_change()})

# %%
multi_df_pct_change.dropna(inplace=True)

# %%
multi_df_pct_change.head()
# Out:
#             BAJAJELEC    FORTIS      IDFC  LALPATHLAB  JKLAKSHMI
# Date
# 2017-05-16   0.017148  0.012911  0.008634    0.011492   0.032694
# 2017-05-17   0.008213 -0.009620 -0.014008    0.000823  -0.021422
# 2017-05-18  -0.045019 -0.043953 -0.029203   -0.002139  -0.072162
# 2017-05-19   0.006286  0.034036 -0.005691    0.000550  -0.019626
# 2017-05-22  -0.068263 -0.042987 -0.015536   -0.000439   0.013204

# %%
BAJAJELEC_daily_name = multi_df_pct_change['BAJAJELEC'].mean()
BAJAJELEC_daily_mean = multi_df_pct_change['BAJAJELEC'].mean()
BAJAJELEC_daily_stdev = multi_df_pct_change['BAJAJELEC'].std()
BAJAJELEC_yearly_mean = BAJAJELEC_daily_mean * 252
BAJAJELEC_yearly_stdev = BAJAJELEC_daily_stdev *(math.sqrt(252))
BAJAJELEC_details = ['BAJAJELEC', BAJAJELEC_daily_mean, BAJAJELEC_daily_stdev, BAJAJELEC_yearly_mean, BAJAJELEC_yearly_stdev]
BAJAJELEC_details
# Out:
# ['BAJAJELEC',
#  0.0012541792961627196,
#  0.025349670997033898,
#  0.31605318263300536,
#  0.4024135516527508]

# %%
def meanDailyReturn( filename ):
    return filename.mean()

def meanDailySTD( filename ):
    return filename.std()

def meanAnnualReturn( filename ):
    return meanDailyReturn(filename) * 252

def meanAnnualSTD( filename ):
    return meanDailySTD(filename) * np.sqrt(252)

# %%
 def read_csv( filename ):   
    if isinstance(filename, pd.DataFrame): return filename  # OPTIMIZATION: allow passthrough of existing dataframe
    
    dataframe = pd.read_csv( filename, parse_dates=['Date'] )
    dataframe.set_index( dataframe.Date, inplace=True )
    return dataframe

def meanDailyReturn( filename ):
    return read_csv( filename ).pct_change.mean()

def meanDailySTD( filename ):
    return read_csv( filename ).pct_change.std()

def meanAnnualReturn( filename ):
    return meanDailyReturn(filename) * 252

def meanAnnualSTD( filename ):
    return meanDailySTD(filename) * np.sqrt(252)

def getName( filename ):
    return re.sub(r'^.+/|\.[^.]+$',     '',    filename)


def calcReturnVolatility( filename ):
    input  = read_csv( filename )
    output = pd.DataFrame([{
        "Name":             getName( filename ),
        "meanDailyReturn":  meanDailyReturn( input ),
        "meanDailySTD":     meanDailySTD( input ),
        "meanAnnualReturn": meanAnnualReturn( input ),
        "meanAnnualSTD":    meanAnnualSTD( input )
    }])
    output.set_index( output.Name, inplace=True, drop=False )
    return output

calcReturnVolatility(infosys_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-92cc6e36b4fb> in <module>()
#      34    return output
#      35
# ---> 36 calcReturnVolatility(infosys_df)
#
# <ipython-input-101-92cc6e36b4fb> in calcReturnVolatility(filename)
#      25    input  = read_csv( filename )
#      26    output = pd.DataFrame([{
# ---> 27        "Name":             getName( filename ),
#      28        "meanDailyReturn":  meanDailyReturn( input ),
#      29        "meanDailySTD":     meanDailySTD( input ),
#
# <ipython-input-101-92cc6e36b4fb> in getName(filename)
#      19
#      20 def getName( filename ):
# ---> 21    return re.sub(r'^.+/|\.[^.]+$',     '',    filename)
#      22
#      23
#
# /usr/lib/python3.6/re.py in sub(pattern, repl, string, count, flags)
#     189     a callable, it's passed the match object and must return
# ...
